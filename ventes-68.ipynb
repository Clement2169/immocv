# %%
import pandas as pd
df = pd.read_csv("../data/annonces-ventes-68.csv",delimiter=';',header=0,encoding="iso-8859-1")
print (df.shape)
display(df.head(10))
# Out:
# (27737, 59)
#                   idannonce type_annonceur typedebien typedetransaction  \
# 0    hektor-robischung-2862             pr          a                 v
# 1            apimo-82452515             pr          m                 v
# 2      immo-facile-52471952             pr          m                 v
# 3      immo-facile-52477215             pr          a                 v
# 4        ag681088-383601401             pr          m                 v
# 5        ag681104-381823822             pr          m                 v
# 6    hektor-robischung-2873             pr          m                 v
# 7        ag681158-383546936             pr          m                 v
# 8        ag751938-380728492             pr          a                 v
# 9  entities-1042950-3869684             pr          m                 v
#
#    etage  surface  surface_terrain  nb_pieces  prix_bien  prix_maison  ...  \
# 0    0.0     64.0              NaN        3.0   128400.0          NaN  ...
# ...
